# %% [markdown]
# Imports

# %%
from sec_certs.dataset.fips import FIPSDataset
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# download datasets

# %%
fips_dataset = FIPSDataset().from_web()
print(f"FIPS dataset: {len(fips_dataset)} certificates")
# Out:
# Downloading: FIPSDataset:   0%|          | 0.00/67.3M [00:00<?, ?B/s]
# Dataset was created with sec-certs version 0.3.2.post1.dev139+g8ab79f0c7 (older than your version 0.4.1). To install the matching version: pip install sec-certs==0.3.2.post1.dev139+g8ab79f0c7
# FIPS dataset: 5208 certificates

# %% [markdown]
# Save dataset

# %%
# Saving the dataset to a local file
print("Saving FIPS dataset")
fips_dataset.to_json("./datasets/FIPS_dataset.json")
print("FIPS dataset saved to /datasets/FIPS_dataset.json")
# Out:
# Saving FIPS dataset
# FIPS dataset saved to /datasets/FIPS_dataset.json

# %% [markdown]
# Load dataset from file

# %%
# Loading the dataset from a local file
fips_dataset = FIPSDataset.from_json('../datasets/FIPS_dataset.json')
